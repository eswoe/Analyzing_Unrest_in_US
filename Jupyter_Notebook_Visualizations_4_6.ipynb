# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pr = pd.read_csv('protests.csv')
pr.describe()
# Out:
#            Attendees  Total Articles
# count   20398.000000    32523.000000
# mean      708.660408        2.797589
# std      9904.943929       11.095795
# min         0.000000        1.000000
# 25%        30.000000        1.000000
# 50%       100.000000        1.000000
# 75%       200.000000        2.000000
# max    725000.000000      923.000000

# %% [markdown]
# 4. In which location were the most frequent events mentioned?

# %%
# find the most frequent event (only the most frequent event is chosen here as there're a larger amount of data)
cnt = pr.groupby(['Event'],as_index=False)['Event'].agg({'Frequency':'count'})
cnt_1 = cnt.sort_values(by=['Frequency'], ascending=False).head(1)

# %%
cnt_10 = cnt.sort_values(by=['Frequency'], ascending=False).head(10)
cnt_10.set_index(['Event'], inplace=True)
cnt_10.to_csv('Qustion4.csv', encoding='utf-8')

cnt_10
# Out:
#                              Frequency
# Event
# Racial Injustice                  7284
# Other                             2113
# Immigration                       2089
# Civil Rights                      1777
# Executive                         1594
# Healthcare                        1341
# Guns                              1340
# Guns (National Walkout Day)       1307
# Collective Bargaining             1296
# Environment                        997

# %%
# choose data from protests.csv and save them into a new dataframe named 'r_4'
evt = list(cnt_1['Event'])
r_4 = pd.DataFrame(columns = ['Date', 'Location', 'Attendees', 'Event', 'Tags', 'Curated', 'Source', 'Total Articles'])
for e in evt:
    result = pr.loc[pr['Event'] == e]
    r_4 = r_4.append(result)

r_4
# Out:
#             Date                                Location  Attendees  \
# 7      2017/1/20   University of Washington, Seattle, WA        NaN
# 470    2017/1/26                 Ped Mall, Iowa City, IA       30.0
# 807     2017/2/7    Lebanon Valley College, Annville, PA       50.0
# 840     2017/2/9   University of Michigan, Ann Arbor, MI      150.0
# 987    2017/2/13                     Charlottesville, VA        NaN
# ...          ...                                     ...        ...
# 32499  2020/8/18            East Liberty, Pittsburgh, PA      300.0
# 32500  2020/8/18                            Portland, OR      200.0
# 32514  2020/8/19  Rock County Courthouse, Janesville, WI       15.0
# 32520  2020/8/19                         East Orange, NJ      100.0
# 32522  2020/8/19                           Milwaukee, WI       10.0
#
#                   Event                                               Tags  \
# 7      Racial Injustice  Civil Rights; For racial justice; Against invi...
# 470    Racial Injustice                   Civil Rights; For racial justice
# 807    Racial Injustice                   Civil Rights; For racial justice
# 840    Racial Injustice  Civil Rights; For racial justice; For religiou...
# 987    Racial Injustice  Civil Rights; For racial justice; Against Conf...
# ...                 ...                                                ...
# 32499  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 32500  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 32514  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 32520  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 32522  Racial Injustice  Civil Rights; For racial justice; For greater ...
#
#       Curated                                             Source  \
# 7         Yes  http://komonews.com/news/local/woman-says-she-...
# 470       Yes  http://fox59.com/2017/01/30/fedex-backs-driver...
# 807       Yes  http://abc27.com/2017/02/07/protestors-push-fo...
# 840       Yes  https://www.michigandaily.com/section/news/stu...
# 987       Yes  http://www.wcyb.com/news/politics/va-gubernato...
# ...       ...                                                ...
# 32499     Yes  https://www.wtae.com/article/watch-live-protes...
# 32500     Yes  https://apnews.com/d640afdd85404f0b7ffde44eb75...
# 32514     Yes  https://www.gazettextra.com/news/local/residen...
# 32520     Yes  https://www.pix11.com/news/local-news/nj-stude...
# 32522     Yes  https://www.jsonline.com/story/communities/nor...
#
#       Total Articles
# 7                  2
# 470                1
# 807                1
# 840                1
# 987                1
# ...              ...
# 32499              5
# 32500              7
# 32514              1
# 32520              1
# 32522              1
#
# [7284 rows x 8 columns]

# %%
# extract the 50 Racial Injustice protests with most attendees and create a new dataframe 'ri_50'
ri_50 = r_4.sort_values(by=['Attendees'], ascending=False).head(50)
ri_50 = ri_50.reset_index()
ri_50
# Out:
#     index       Date                                  Location  Attendees  \
# 0   16065  2019/1/21                           San Antonio, TX   300000.0
# 1   22698  2020/1/20    Pittman-Sullivan Park, San Antonio, TX   100000.0
# 2   28774  2020/6/12                               Seattle, WA    60000.0
# 3   26977   2020/6/5                               Houston, TX    60000.0
# 4   25962   2020/6/2                               Houston, TX    25000.0
# 5   27424   2020/6/6                   Union Park, Chicago, IL    20000.0
# 6   27954   2020/6/7                Hollywood, Los Angeles, CA    20000.0
# 7   25660   2020/6/1                               Oakland, CA    15000.0
# 8   29214  2020/6/14                              Brooklyn, NY    15000.0
# 9   27696   2020/6/6           Civic Center Park, Berkeley, CA    12000.0
# 10  27771   2020/6/6                            St. George, UT    10200.0
# 11  26255   2020/6/2           West Hollywood, Los Angeles, CA    10000.0
# 12  26649   2020/6/4                             Nashville, TN    10000.0
# 13  27595   2020/6/6                State Capitol, Waikiki, HI    10000.0
# 14  27821   2020/6/6                               Orlando, FL    10000.0
# 15  22713  2020/1/20               State Capitol, Columbia, SC    10000.0
# 16  26378   2020/6/3  Tom McCall Waterfront Park, Portland, OR    10000.0
# 17  26370   2020/6/3                         San Francisco, CA    10000.0
# 18  26345   2020/6/3                    City Hall, Seattle, WA    10000.0
# 19  27370   2020/6/6          Lincoln Memorial, Washington, DC    10000.0
# 20  25979   2020/6/2                              Portland, OR    10000.0
# 21  24473  2020/5/27               Powderhorn, Minneapolis, MN     8000.0
# 22  27962   2020/6/7                 Riverfront Park, Troy, NY     8000.0
# 23  24597  2020/5/29                               Oakland, CA     7500.0
# 24  27996   2020/6/7                             Milwaukee, WI     7500.0
# 25  25098  2020/5/31                                Eugene, OR     7000.0
# 26  25112  2020/5/31                               Lincoln, NE     7000.0
# 27  27582   2020/6/6                    City Hall, Seattle, WA     7000.0
# 28  27345   2020/6/6                            Bellingham, WA     7000.0
# 29  26020   2020/6/2             Lower Manhattan, New York, NY     6500.0
# 30  28245   2020/6/8                               Houston, TX     6000.0
# 31  26543   2020/6/3                            Santa Cruz, CA     6000.0
# 32  28137   2020/6/7                            Montpelier, VT     5000.0
# 33  16157  2019/1/22                Westlake Park, Seattle, WA     5000.0
# 34  26999   2020/6/5             State Capitol, Providence, RI     5000.0
# 35  31300  2020/7/25                 Capitol Hill, Seattle, WA     5000.0
# 36  25127  2020/5/31                           Minneapolis, MN     5000.0
# 37  26788   2020/6/4                              New York, NY     5000.0
# 38  24734  2020/5/30                                Newark, NJ     5000.0
# 39  31343  2020/7/25                              Portland, OR     5000.0
# 40  25614   2020/6/1                           Asbury Park, NJ     5000.0
# 41  24821  2020/5/30              Travis Park, San Antonio, TX     5000.0
# 42  27557   2020/6/6                           Northampton, MA     4500.0
# 43  26232   2020/6/2                                Quincy, MA     4500.0
# 44  28028   2020/6/7                            Portsmouth, NH     4000.0
# 45  27359   2020/6/6        Cesar Chavez Plaza, Sacramento, CA     4000.0
# 46  25608   2020/6/1                   Downtown, Riverside, CA     4000.0
# 47  28001   2020/6/7                               Merrick, NY     4000.0
# 48  25407  2020/5/31                               Oakland, CA     4000.0
# 49  25332  2020/5/31                               Orlando, FL     4000.0
#
#                Event                                               Tags  \
# 0   Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 1   Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 2   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 3   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 4   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 5   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 6   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 7   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 8   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 9   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 10  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 11  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 12  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 13  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 14  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 15  Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 16  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 17  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 18  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 19  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 20  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 21  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 22  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 23  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 24  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 25  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 26  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 27  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 28  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 29  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 30  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 31  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 32  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 33  Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 34  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 35  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 36  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 37  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 38  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 39  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 40  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 41  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 42  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 43  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 44  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 45  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 46  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 47  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 48  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 49  Racial Injustice  Civil Rights; For racial justice; For greater ...
#
#    Curated                                             Source Total Articles
# 0      Yes  https://www.kens5.com/article/news/east-side-w...              3
# 1      Yes  https://www.mysanantonio.com/news/local/articl...              5
# 2      Yes  https://www.seattletimes.com/seattle-news/seat...             11
# 3      Yes  http://www.salamancapress.com/houston-hip-hop-...              2
# 4      Yes  https://www.washingtonpost.com/local/new-fenci...             33
# 5      Yes  https://www.chicagotribune.com/news/breaking/c...              5
# 6      Yes  https://www.latimes.com/california/story/2020-...              5
# 7      Yes  https://www.sfchronicle.com/bayarea/article/Cr...             14
# 8      Yes  https://www.kiro7.com/news/trending/thousands-...              5
# 9      Yes  https://www.dailycal.org/2020/06/07/we-wont-st...              7
# 10     Yes  https://www.stgeorgeutah.com/news/archive/2020...              1
# 11     Yes  https://www.dailynews.com/hundreds-come-out-ag...              2
# 12     Yes  https://www.tennessean.com/story/news/local/20...             14
# 13     Yes  https://www.khon2.com/local-news/around-200-in...              4
# 14     Yes  https://www.orlandosentinel.com/news/breaking-...              1
# 15     Yes  https://www.latimes.com/world-nation/story/202...             12
# 16     Yes  https://www.kptv.com/news/portland-enters-8th-...             77
# 17     Yes  https://www.usatoday.com/story/news/nation/202...             10
# 18     Yes  https://www.kiro7.com/news/local/thousands-mar...             15
# 19     Yes  https://www.reuters.com/article/us-minneapolis...             47
# 20     Yes  https://apnews.com/4a17b21e265257dd9ebaf09cd72...             83
# 21     Yes  https://abcnews.go.com/US/dangerous-protests-e...             59
# 22     Yes  https://www.nny360.com/top_stories/fort-drum-s...             13
# 23     Yes  https://www.wsbtv.com/news/trending/police-pre...             83
# 24     Yes  https://www.jsonline.com/story/news/2020/06/07...              7
# 25     Yes  https://www.dailyemerald.com/news/police-fire-...             23
# 26     Yes  https://journalstar.com/news/local/watch-now-t...              5
# 27     Yes  https://www.seattletimes.com/seattle-news/seat...              8
# 28     Yes  https://www.bellinghamherald.com/news/local/ar...              5
# 29     Yes  https://www.northjersey.com/story/news/new-yor...              7
# 30     Yes  https://www.tribtoday.com/news/latest-news/202...              4
# 31     Yes  https://pajaronian.com/police-taking-barbaric-...              5
# 32     Yes  https://vtdigger.org/2020/06/07/vermonters-pro...              3
# 33     Yes  https://www.seattlepi.com/seattlenews/article/...              1
# 34     Yes  https://www.providencejournal.com/news/2020060...             12
# 35     Yes  https://www.nytimes.com/2020/07/25/us/protests...             73
# 36     Yes  https://www.foxnews.com/us/minnesota-truck-inc...             43
# 37     Yes  https://www.amny.com/new-york/live-updates-day...              2
# 38     Yes  https://www.northjersey.com/story/news/local/2...             24
# 39     Yes  https://www.oregonlive.com/crime/2020/07/insid...             82
# 40     Yes  https://www.app.com/story/news/local/community...             19
# 41     Yes  https://www.mysanantonio.com/news/local/articl...             19
# 42     Yes  https://www.gazettenet.com/Black-Trans-Lives-i...              4
# 43     Yes  https://www.patriotledger.com/news/20200602/th...              1
# 44     Yes  https://www.fosters.com/news/20200607/rsquosay...              4
# 45     Yes  https://www.sacbee.com/news/local/article24333...              9
# 46     Yes  https://www.desertsun.com/story/news/2020/06/0...             13
# 47     Yes  https://www.newsday.com/long-island/suffolk/sa...              1
# 48     Yes  https://www.ktvu.com/news/emotions-run-high-as...              3
# 49     Yes  https://www.orlandosentinel.com/news/breaking-...              7

# %%
# split the locations and switch its orders to extract information on state and towns
loc = ri_50['Location'].str.split(',', -1)

cleaned_addr = []
for l in list(loc):
    if len(l) == 2:
        l[0],l[1] = l[1],l[0]
        cleaned_addr.append(l)
    if len(l) == 3:
        l[0],l[1],l[2] = l[2],l[1],l[0]
        cleaned_addr.append(l)

# %%
columns = ['State','City','Address']
addr = pd.DataFrame(cleaned_addr[0:], columns = columns)
addr
# Out:
#    State           City                     Address
# 0     TX    San Antonio                        None
# 1     TX    San Antonio       Pittman-Sullivan Park
# 2     WA        Seattle                        None
# 3     TX        Houston                        None
# 4     TX        Houston                        None
# 5     IL        Chicago                  Union Park
# 6     CA    Los Angeles                   Hollywood
# 7     CA        Oakland                        None
# 8     NY       Brooklyn                        None
# 9     CA       Berkeley           Civic Center Park
# 10    UT     St. George                        None
# 11    CA    Los Angeles              West Hollywood
# 12    TN      Nashville                        None
# 13    HI        Waikiki               State Capitol
# 14    FL        Orlando                        None
# 15    SC       Columbia               State Capitol
# 16    OR       Portland  Tom McCall Waterfront Park
# 17    CA  San Francisco                        None
# 18    WA        Seattle                   City Hall
# 19    DC     Washington            Lincoln Memorial
# 20    OR       Portland                        None
# 21    MN    Minneapolis                  Powderhorn
# 22    NY           Troy             Riverfront Park
# 23    CA        Oakland                        None
# 24    WI      Milwaukee                        None
# 25    OR         Eugene                        None
# 26    NE        Lincoln                        None
# 27    WA        Seattle                   City Hall
# 28    WA     Bellingham                        None
# 29    NY       New York             Lower Manhattan
# 30    TX        Houston                        None
# 31    CA     Santa Cruz                        None
# 32    VT     Montpelier                        None
# 33    WA        Seattle               Westlake Park
# 34    RI     Providence               State Capitol
# 35    WA        Seattle                Capitol Hill
# 36    MN    Minneapolis                        None
# 37    NY       New York                        None
# 38    NJ         Newark                        None
# 39    OR       Portland                        None
# 40    NJ    Asbury Park                        None
# 41    TX    San Antonio                 Travis Park
# 42    MA    Northampton                        None
# 43    MA         Quincy                        None
# 44    NH     Portsmouth                        None
# 45    CA     Sacramento          Cesar Chavez Plaza
# 46    CA      Riverside                    Downtown
# 47    NY        Merrick                        None
# 48    CA        Oakland                        None
# 49    FL        Orlando                        None

# %%
# add columns of 'addr' into dataframe 'ri_50'
ri_50['State'] = ''
ri_50['City'] = ''
ri_50['Address'] = ''

ri_50['State'] = addr['State']
ri_50['City'] = addr['City']
ri_50['Address'] = addr['Address']
ri_50
# Out:
#     index       Date                                  Location  Attendees  \
# 0   16065  2019/1/21                           San Antonio, TX   300000.0
# 1   22698  2020/1/20    Pittman-Sullivan Park, San Antonio, TX   100000.0
# 2   28774  2020/6/12                               Seattle, WA    60000.0
# 3   26977   2020/6/5                               Houston, TX    60000.0
# 4   25962   2020/6/2                               Houston, TX    25000.0
# 5   27424   2020/6/6                   Union Park, Chicago, IL    20000.0
# 6   27954   2020/6/7                Hollywood, Los Angeles, CA    20000.0
# 7   25660   2020/6/1                               Oakland, CA    15000.0
# 8   29214  2020/6/14                              Brooklyn, NY    15000.0
# 9   27696   2020/6/6           Civic Center Park, Berkeley, CA    12000.0
# 10  27771   2020/6/6                            St. George, UT    10200.0
# 11  26255   2020/6/2           West Hollywood, Los Angeles, CA    10000.0
# 12  26649   2020/6/4                             Nashville, TN    10000.0
# 13  27595   2020/6/6                State Capitol, Waikiki, HI    10000.0
# 14  27821   2020/6/6                               Orlando, FL    10000.0
# 15  22713  2020/1/20               State Capitol, Columbia, SC    10000.0
# 16  26378   2020/6/3  Tom McCall Waterfront Park, Portland, OR    10000.0
# 17  26370   2020/6/3                         San Francisco, CA    10000.0
# 18  26345   2020/6/3                    City Hall, Seattle, WA    10000.0
# 19  27370   2020/6/6          Lincoln Memorial, Washington, DC    10000.0
# 20  25979   2020/6/2                              Portland, OR    10000.0
# 21  24473  2020/5/27               Powderhorn, Minneapolis, MN     8000.0
# 22  27962   2020/6/7                 Riverfront Park, Troy, NY     8000.0
# 23  24597  2020/5/29                               Oakland, CA     7500.0
# 24  27996   2020/6/7                             Milwaukee, WI     7500.0
# 25  25098  2020/5/31                                Eugene, OR     7000.0
# 26  25112  2020/5/31                               Lincoln, NE     7000.0
# 27  27582   2020/6/6                    City Hall, Seattle, WA     7000.0
# 28  27345   2020/6/6                            Bellingham, WA     7000.0
# 29  26020   2020/6/2             Lower Manhattan, New York, NY     6500.0
# 30  28245   2020/6/8                               Houston, TX     6000.0
# 31  26543   2020/6/3                            Santa Cruz, CA     6000.0
# 32  28137   2020/6/7                            Montpelier, VT     5000.0
# 33  16157  2019/1/22                Westlake Park, Seattle, WA     5000.0
# 34  26999   2020/6/5             State Capitol, Providence, RI     5000.0
# 35  31300  2020/7/25                 Capitol Hill, Seattle, WA     5000.0
# 36  25127  2020/5/31                           Minneapolis, MN     5000.0
# 37  26788   2020/6/4                              New York, NY     5000.0
# 38  24734  2020/5/30                                Newark, NJ     5000.0
# 39  31343  2020/7/25                              Portland, OR     5000.0
# 40  25614   2020/6/1                           Asbury Park, NJ     5000.0
# 41  24821  2020/5/30              Travis Park, San Antonio, TX     5000.0
# 42  27557   2020/6/6                           Northampton, MA     4500.0
# 43  26232   2020/6/2                                Quincy, MA     4500.0
# 44  28028   2020/6/7                            Portsmouth, NH     4000.0
# 45  27359   2020/6/6        Cesar Chavez Plaza, Sacramento, CA     4000.0
# 46  25608   2020/6/1                   Downtown, Riverside, CA     4000.0
# 47  28001   2020/6/7                               Merrick, NY     4000.0
# 48  25407  2020/5/31                               Oakland, CA     4000.0
# 49  25332  2020/5/31                               Orlando, FL     4000.0
#
#                Event                                               Tags  \
# 0   Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 1   Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 2   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 3   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 4   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 5   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 6   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 7   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 8   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 9   Racial Injustice  Civil Rights; For racial justice; For greater ...
# 10  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 11  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 12  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 13  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 14  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 15  Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 16  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 17  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 18  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 19  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 20  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 21  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 22  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 23  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 24  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 25  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 26  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 27  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 28  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 29  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 30  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 31  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 32  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 33  Racial Injustice  Civil Rights; For racial justice; Martin Luthe...
# 34  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 35  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 36  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 37  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 38  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 39  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 40  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 41  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 42  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 43  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 44  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 45  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 46  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 47  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 48  Racial Injustice  Civil Rights; For racial justice; For greater ...
# 49  Racial Injustice  Civil Rights; For racial justice; For greater ...
#
#    Curated                                             Source Total Articles  \
# 0      Yes  https://www.kens5.com/article/news/east-side-w...              3
# 1      Yes  https://www.mysanantonio.com/news/local/articl...              5
# 2      Yes  https://www.seattletimes.com/seattle-news/seat...             11
# 3      Yes  http://www.salamancapress.com/houston-hip-hop-...              2
# 4      Yes  https://www.washingtonpost.com/local/new-fenci...             33
# 5      Yes  https://www.chicagotribune.com/news/breaking/c...              5
# 6      Yes  https://www.latimes.com/california/story/2020-...              5
# 7      Yes  https://www.sfchronicle.com/bayarea/article/Cr...             14
# 8      Yes  https://www.kiro7.com/news/trending/thousands-...              5
# 9      Yes  https://www.dailycal.org/2020/06/07/we-wont-st...              7
# 10     Yes  https://www.stgeorgeutah.com/news/archive/2020...              1
# 11     Yes  https://www.dailynews.com/hundreds-come-out-ag...              2
# 12     Yes  https://www.tennessean.com/story/news/local/20...             14
# 13     Yes  https://www.khon2.com/local-news/around-200-in...              4
# 14     Yes  https://www.orlandosentinel.com/news/breaking-...              1
# 15     Yes  https://www.latimes.com/world-nation/story/202...             12
# 16     Yes  https://www.kptv.com/news/portland-enters-8th-...             77
# 17     Yes  https://www.usatoday.com/story/news/nation/202...             10
# 18     Yes  https://www.kiro7.com/news/local/thousands-mar...             15
# 19     Yes  https://www.reuters.com/article/us-minneapolis...             47
# 20     Yes  https://apnews.com/4a17b21e265257dd9ebaf09cd72...             83
# 21     Yes  https://abcnews.go.com/US/dangerous-protests-e...             59
# 22     Yes  https://www.nny360.com/top_stories/fort-drum-s...             13
# 23     Yes  https://www.wsbtv.com/news/trending/police-pre...             83
# 24     Yes  https://www.jsonline.com/story/news/2020/06/07...              7
# 25     Yes  https://www.dailyemerald.com/news/police-fire-...             23
# 26     Yes  https://journalstar.com/news/local/watch-now-t...              5
# 27     Yes  https://www.seattletimes.com/seattle-news/seat...              8
# 28     Yes  https://www.bellinghamherald.com/news/local/ar...              5
# 29     Yes  https://www.northjersey.com/story/news/new-yor...              7
# 30     Yes  https://www.tribtoday.com/news/latest-news/202...              4
# 31     Yes  https://pajaronian.com/police-taking-barbaric-...              5
# 32     Yes  https://vtdigger.org/2020/06/07/vermonters-pro...              3
# 33     Yes  https://www.seattlepi.com/seattlenews/article/...              1
# 34     Yes  https://www.providencejournal.com/news/2020060...             12
# 35     Yes  https://www.nytimes.com/2020/07/25/us/protests...             73
# 36     Yes  https://www.foxnews.com/us/minnesota-truck-inc...             43
# 37     Yes  https://www.amny.com/new-york/live-updates-day...              2
# 38     Yes  https://www.northjersey.com/story/news/local/2...             24
# 39     Yes  https://www.oregonlive.com/crime/2020/07/insid...             82
# 40     Yes  https://www.app.com/story/news/local/community...             19
# 41     Yes  https://www.mysanantonio.com/news/local/articl...             19
# 42     Yes  https://www.gazettenet.com/Black-Trans-Lives-i...              4
# 43     Yes  https://www.patriotledger.com/news/20200602/th...              1
# 44     Yes  https://www.fosters.com/news/20200607/rsquosay...              4
# 45     Yes  https://www.sacbee.com/news/local/article24333...              9
# 46     Yes  https://www.desertsun.com/story/news/2020/06/0...             13
# 47     Yes  https://www.newsday.com/long-island/suffolk/sa...              1
# 48     Yes  https://www.ktvu.com/news/emotions-run-high-as...              3
# 49     Yes  https://www.orlandosentinel.com/news/breaking-...              7
#
#    State           City                     Address
# 0     TX    San Antonio                        None
# 1     TX    San Antonio       Pittman-Sullivan Park
# 2     WA        Seattle                        None
# 3     TX        Houston                        None
# 4     TX        Houston                        None
# 5     IL        Chicago                  Union Park
# 6     CA    Los Angeles                   Hollywood
# 7     CA        Oakland                        None
# 8     NY       Brooklyn                        None
# 9     CA       Berkeley           Civic Center Park
# 10    UT     St. George                        None
# 11    CA    Los Angeles              West Hollywood
# 12    TN      Nashville                        None
# 13    HI        Waikiki               State Capitol
# 14    FL        Orlando                        None
# 15    SC       Columbia               State Capitol
# 16    OR       Portland  Tom McCall Waterfront Park
# 17    CA  San Francisco                        None
# 18    WA        Seattle                   City Hall
# 19    DC     Washington            Lincoln Memorial
# 20    OR       Portland                        None
# 21    MN    Minneapolis                  Powderhorn
# 22    NY           Troy             Riverfront Park
# 23    CA        Oakland                        None
# 24    WI      Milwaukee                        None
# 25    OR         Eugene                        None
# 26    NE        Lincoln                        None
# 27    WA        Seattle                   City Hall
# 28    WA     Bellingham                        None
# 29    NY       New York             Lower Manhattan
# 30    TX        Houston                        None
# 31    CA     Santa Cruz                        None
# 32    VT     Montpelier                        None
# 33    WA        Seattle               Westlake Park
# 34    RI     Providence               State Capitol
# 35    WA        Seattle                Capitol Hill
# 36    MN    Minneapolis                        None
# 37    NY       New York                        None
# 38    NJ         Newark                        None
# 39    OR       Portland                        None
# 40    NJ    Asbury Park                        None
# 41    TX    San Antonio                 Travis Park
# 42    MA    Northampton                        None
# 43    MA         Quincy                        None
# 44    NH     Portsmouth                        None
# 45    CA     Sacramento          Cesar Chavez Plaza
# 46    CA      Riverside                    Downtown
# 47    NY        Merrick                        None
# 48    CA        Oakland                        None
# 49    FL        Orlando                        None

# %%
# convert 'ri_50' into a new csv
ri_50.to_csv('q4_cleaned.csv', encoding='utf-8')

# %%
# Coordinate for each event is added into the 'ri_50' dataframe in Florish, 
#   using the Flourish dataset about coordinates for every states (in the US map format)

# %% [markdown]
# 6. What type of protests were common at universities/colleges versus high schools?

# %%
# (all files named as Question 7 is for Question 6 in the final version)
uni = pr[pr['Location'].str.contains('University' or 'College')]
hs = pr[pr['Location'].str.contains('High School')]

# %%
tpu = uni.groupby(['Event'],as_index=False)['Event'].agg({'University and College':'count'})
tpu_1 = tpu.sort_values(by=['University and College'], ascending=False).head(10)

tph = hs.groupby(['Event'],as_index=False)['Event'].agg({'High School':'count'})
tph_1 = tph.sort_values(by=['High School'], ascending=False).head(10)

tpu_1
# Out:
#                                    Event  University and College
# 80                      Racial Injustice                     164
# 14                 Collective Bargaining                      95
# 0                           Civil Rights                      82
# 17                             Education                      69
# 59                                 Other                      67
# 49                           Immigration                      63
# 30                           Environment                      49
# 45           Guns (National Walkout Day)                      29
# 53               International Relations                      27
# 40  Executive (Supreme Court Nomination)                      27

# %%
tph_1
# Out:
#                           Event  High School
# 30  Guns (National Walkout Day)          888
# 27                         Guns          429
# 10                    Education          101
# 44             Racial Injustice           68
# 24                  Environment           46
# 15          Education (Funding)           30
# 31      Guns (Second Amendment)           26
# 0                  Civil Rights           26
# 8         Collective Bargaining           24
# 39                        Other           23

# %%
# merge results and create sns plot
result_7 = pd.merge(tph_1, tpu_1, how='outer', on=['Event'])
result_7.set_index(['Event'], inplace=True)

# %%
result_7.to_csv('Q7.csv', encoding='utf_8')

# %%
plt7 = result_7.plot(kind = 'bar', title = 'Most Frequent Events')
plt7.set_xlabel('Category')
plt7.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
tpu.to_csv('Q7_tpu_full.csv', encoding='utf_8')
tph.to_csv('Q7_tph_full.csv', encoding='utf_8')

# %%
# Visualizations were made in Flourish
